# %% [markdown]
# <a href="https://colab.research.google.com/github/joanniv/ImportfromColab/blob/main/Workshop01Mar25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Jupyter!")
# Out:
# Hello Jupyter!

# %%
# prompt: create a dataframe with 10 rows and 5 columns

import pandas as pd
import numpy as np

data = np.random.rand(10, 5)
df = pd.DataFrame(data)
df
# Out:
#           0         1         2         3         4
# 0  0.185998  0.422444  0.544332  0.953360  0.004564
# 1  0.601897  0.352553  0.114490  0.496001  0.234516
# 2  0.400089  0.983084  0.504930  0.802877  0.384141
# 3  0.253208  0.772795  0.276038  0.214939  0.817843
# 4  0.218973  0.763717  0.580649  0.890233  0.290955
# 5  0.950321  0.200641  0.435979  0.620659  0.967470
# 6  0.160849  0.111877  0.619383  0.339400  0.303033
# 7  0.772347  0.377580  0.923550  0.506389  0.551732
# 8  0.461158  0.671375  0.615087  0.025625  0.608795
# 9  0.790560  0.902550  0.424778  0.805759  0.016376

# %% [markdown]
# #  Learning markdown
# ## **Another** language to learn for collaborations
#
# *To learn or not to learn, that is the question*. The languages I know so far are as follows
# * English
# * Hindi
# *Tamil
# *Malayalam
# *Spanish
#
# Yet, over the last few weeks, I've ended up learning two new languages, or at least the basics of it. This is the 2 ^nd^ day of the *Foundations of Python Programming* workshop. Now I am programming ~~illiterate~~ literate.
